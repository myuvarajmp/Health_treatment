# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### What are the strongest predictors of mental health illness or certain attitudes towards mental health in the workplace?

# %% [markdown]
# ## Data Description

# %% [markdown]
# * **Timestamp**
# * **Age**
# * **Gender**
# * **Country**
# * **state:** If you live in the United States, which state or territory do you live in?
# * **self_employed:** Are you self-employed?
# * **family_history:** Do you have a family history of mental illness?
# * **treatment:** Have you sought treatment for a mental health condition?
# * **work_interfere:** If you have a mental health condition, do you feel that it interferes with your work?
# * **no_employees:** How many employees does your company or organization have?
# * **remote_work:** Do you work remotely (outside of an office) at least 50% of the time?
# * **tech_company:** Is your employer primarily a tech company/organization?
# * **benefits:** Does your employer provide mental health benefits?
# * **care_options:** Do you know the options for mental health care your employer provides?
# * **wellness_program:** Has your employer ever discussed mental health as part of an employee wellness program?
# * **seek_help:** Does your employer provide resources to learn more about mental health issues and how to seek help?
# * **anonymity:** Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
# * **leave:** How easy is it for you to take medical leave for a mental health condition?
# * **mentalhealthconsequence:** Do you think that discussing a mental health issue with your employer would have negative consequences?
# * **physhealthconsequence:** Do you think that discussing a physical health issue with your employer would have negative consequences?
# * **coworkers:** Would you be willing to discuss a mental health issue with your coworkers?
# * **supervisor:** Would you be willing to discuss a mental health issue with your direct suervisor(s)?
# * **mentalhealthinterview:** Would you bring up a mental health issue with a potential employer in an interview?
# * **physhealthinterview:** Would you bring up a physical health issue with a potential employer in an interview?
# * **mentalvsphysical:** Do you feel that your employer takes mental health as seriously as physical health?
# * **obs_consequence:** Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import randint

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.datasets import make_classification
from sklearn.preprocessing import binarize, LabelEncoder, MinMaxScaler

# models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.model_selection import RandomizedSearchCV

#Bagging
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier

#Naive bayes
from sklearn.naive_bayes import GaussianNB 

#Stacking
from mlxtend.classifier import StackingClassifier


# Validation libraries
from sklearn import metrics
from sklearn.metrics import accuracy_score, mean_squared_error, precision_recall_curve,classification_report
from sklearn.model_selection import cross_val_score,  cross_validate

# %%
df = pd.read_csv('survey.csv')

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df.shape
# Out:
# (1259, 27)

# %%
df.dtypes
# Out:
# Timestamp                    object
# Age                           int64
# Gender                       object
# Country                      object
# state                        object
# self_employed                object
# family_history               object
# treatment                    object
# work_interfere               object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# wellness_program             object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_health_interview      object
# phys_health_interview        object
# mental_vs_physical           object
# obs_consequence              object
# ...

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = round(((df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)*100),3)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
print(missing_data)
# Out:
#                            Total  Percent
# comments                    1095   86.974
# state                        515   40.905
# work_interfere               264   20.969
# self_employed                 18    1.430
# benefits                       0    0.000
# Age                            0    0.000
# Gender                         0    0.000
# Country                        0    0.000
# family_history                 0    0.000
# treatment                      0    0.000
# no_employees                   0    0.000
# remote_work                    0    0.000
# tech_company                   0    0.000
# care_options                   0    0.000
# obs_consequence                0    0.000
# wellness_program               0    0.000
# seek_help                      0    0.000
# anonymity                      0    0.000
# leave                          0    0.000
# mental_health_consequence      0    0.000
# phys_health_consequence        0    0.000
# ...

# %%
#Removing columns 'comments','state','work_interfere' from our dataset


df = df.drop('comments',axis=1)
df = df.drop('state',axis=1)
df = df.drop('Timestamp',axis=1)

# %%
# Assign default values for each data type
defaultInt = 0
defaultString = 'NaN'

for feature in df:
    if df[feature].dtypes == 'object':
        df[feature] = df[feature].fillna(defaultString)
    elif df[feature].dtypes == 'int':
        df[feature] = df[feature].fillna(defaultInt)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
df['Gender'] = df['Gender'].str.lower()

# %%
Male = ["male", "m", "male-ish", "maile", "mal", "male (cis)", "make", "male ", "man","msle", "mail", "malr","cis man", "Cis Male", "cis male"]
Trans = ["trans-female", "something kinda male?", "queer/she/they", "non-binary","nah", "all", "enby", "fluid", "genderqueer", "androgyne", "agender", "male leaning androgynous", "guy (-ish) ^_^", "trans woman", "neuter", "female (trans)", "queer", "ostensibly male, unsure what that really means"]           
Female = ["cis female", "f", "female", "woman",  "femake", "female ","cis-female/femme", "female (cis)", "femail"]

for i in df['Gender']:
    if i in Male:
        df['Gender'] = df['Gender'].replace({i:'Male'})
    elif i in Female:
        df['Gender'] = df['Gender'].replace({i:'Female'})
    elif i in Trans:
        df['Gender'] = df['Gender'].replace({i:'Trans'})

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Trans', 'a little about you', 'p'], dtype=object)

# %%
df[df['Gender'] == 'a little about you']
# Out:
#      Age              Gender       Country self_employed family_history  \
# 989    8  a little about you  Bahamas, The           Yes            Yes
#
#     treatment work_interfere no_employees remote_work tech_company  ...  \
# 989       Yes          Often          1-5         Yes          Yes  ...
#
#     anonymity      leave mental_health_consequence phys_health_consequence  \
# 989       Yes  Very easy                       Yes                     Yes
#
#     coworkers supervisor mental_health_interview phys_health_interview  \
# 989       Yes        Yes                     Yes                   Yes
#
#     mental_vs_physical obs_consequence
# 989                Yes             Yes
#
# [1 rows x 24 columns]

# %%
df[df['Gender'] == 'p']
# Out:
#       Age Gender        Country self_employed family_history treatment  \
# 1127   -1      p  United States           Yes            Yes       Yes
#
#      work_interfere no_employees remote_work tech_company  ... anonymity  \
# 1127          Often          1-5         Yes          Yes  ...       Yes
#
#           leave mental_health_consequence phys_health_consequence coworkers  \
# 1127  Very easy                       Yes                     Yes       Yes
#
#      supervisor mental_health_interview phys_health_interview  \
# 1127        Yes                     Yes                   Yes
#
#      mental_vs_physical obs_consequence
# 1127                Yes             Yes
#
# [1 rows x 24 columns]

# %%
#both the above two entries seems very odd. removing them from our data
df.drop(df[df['Gender'] == 'a little about you'].index,inplace=True)
df.drop(df[df['Gender'] == 'p'].index,inplace=True)

# %%
plt.figure(figsize=(8, 20))
df['Age'].value_counts().plot(kind= 'barh')

# %%
#certain Age entries like '-1726','-29','5' seems odd. we will remove them from our data

#both the above two entries seems very odd. removing them from our data
df.drop(df[df['Age'] == 5].index,inplace=True)
df.drop(df[df['Age'] == -29].index,inplace=True)
df.drop(df[df['Age'] == 329].index,inplace=True)
df.drop(df[df['Age'] == -1726].index,inplace=True)
df.drop(df[df['Age'] == 99999999999].index,inplace=True)
df.drop(df[df['Age'] == 11].index,inplace=True)

# %%
df['self_employed'].unique()
# Out:
# array(['NaN', 'Yes', 'No'], dtype=object)

# %%
df['self_employed'].value_counts()
# Out:
# No     1091
# Yes     142
# NaN      18
# Name: self_employed, dtype: int64

# %%
df['self_employed'] = df['self_employed'].replace({'NaN':'No'})

# %%
df.head()
# Out:
#    Age  Gender         Country self_employed family_history treatment  \
# 0   37  Female   United States            No             No       Yes
# 1   44    Male   United States            No             No        No
# 2   32    Male          Canada            No             No        No
# 3   31    Male  United Kingdom            No            Yes       Yes
# 4   31    Male   United States            No             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely            6-25          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df['work_interfere'].unique()
# Out:
# array(['Often', 'Rarely', 'Never', 'Sometimes', 'NaN'], dtype=object)

# %%
df['work_interfere'].value_counts()
# Out:
# Sometimes    464
# NaN          262
# Never        212
# Rarely       173
# Often        140
# Name: work_interfere, dtype: int64

# %%
#Since it will be difficult to put 20% of NaN in one category, we will create a new category for NaN.
#lets replace NaN's with 'Don't know'.
df['work_interfere'] = df['work_interfere'].replace({'NaN':'Don\'t Know'})

# %%
df.shape
# Out:
# (1251, 24)

# %% [markdown]
# ### Univariate Analysis

# %%
X = df.drop('treatment',axis=1)
y = df['treatment']

# %%
# Distribiution and density by Age
plt.figure(figsize=(12,8))
sns.distplot(df["Age"])
plt.title("Distribuition and density by Age")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize=(20,40))
for i in range(1,len(X.columns)):
    plt.subplot(8,3,i)
    X[X.columns[i]].value_counts().plot(kind='barh')
    plt.xlabel(X.columns[i])
plt.show()

# %% [markdown]
# #### Insights:
#
# * Most of the samples in our data are male
# * Around 200 samples in our data are self-employee
# * Work does interfere in mental illness for half of our sample
# * Majority of our samples dont have option to work remotely
# * Majority of our samples are working in tech company
# * 1/3rd of our sample are not aware or don't get mental health benefits from employers
# * Employers are mostly not discussing about mental health in wellness programs
# * Majority of the samples are not able to or don't know to take leave for mental health conditions
# * Majority of the samples are not ready to discuss mental health conditions in interview but ready to discuss about physical health issue
# * Majority of the samples have not observed coworkers having negative consequences with mental health conditions

# %% [markdown]
# ## Bivariate Analysis

# %%
# Separate by treatment or not
g = sns.FacetGrid(df, col='treatment', height=6)
g = g.map(sns.distplot, "Age")

# %%
# Age of samples with and without treatment is normally distributed.

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'tech_company', 'benefits', 'care_options', 'wellness_program',
#        'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
# Let see how many people has been treated
plt.figure(figsize=(8,6))
#labels = labelDict['label_Gender']
g = sns.countplot(x="treatment", data=df)
#g.set_xticklabels(labels)

plt.title('Total Distribuition by treated or not')
# Out:
# Text(0.5, 1.0, 'Total Distribuition by treated or not')

# %%
df = df.drop('Country',axis=1)

# %%
cat_var = ['Gender','treatment' ,'self_employed', 'family_history','work_interfere', 'no_employees', 'remote_work',
          'tech_company', 'benefits', 'care_options', 'wellness_program',
       'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
       'phys_health_consequence', 'coworkers', 'supervisor',
       'mental_health_interview', 'phys_health_interview',
       'mental_vs_physical', 'obs_consequence']

# %%
dummies = pd.get_dummies(df[cat_var], drop_first = True)
df = pd.concat([df, dummies],axis=1)

# %%
df.drop(cat_var,axis=1,inplace = True)

# %%
df = df.rename(columns={'treatment_Yes':'treatment'})

# %% [markdown]
# ### Rescaling the Features

# %%
# Scaling Age
scaler = MinMaxScaler()
df['Age'] = scaler.fit_transform(df[['Age']])
df.head()
# Out:
#         Age  Gender_Male  Gender_Trans  treatment  self_employed_Yes  \
# 0  0.351852            0             0          1                  0
# 1  0.481481            1             0          0                  0
# 2  0.259259            1             0          0                  0
# 3  0.240741            1             0          1                  0
# 4  0.240741            1             0          0                  0
#
#    family_history_Yes  work_interfere_Never  work_interfere_Often  \
# 0                   0                     0                     1
# 1                   0                     0                     0
# 2                   0                     0                     0
# 3                   1                     0                     1
# 4                   0                     1                     0
#
#    work_interfere_Rarely  work_interfere_Sometimes  ...  coworkers_Yes  \
# 0                      0                         0  ...              0
# ...

# %% [markdown]
# ## Model Building

# %%
# Train test split
X= df.drop(columns=['treatment'])
y= df[['treatment']]

np.random.seed(0)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=100)

# %%
def evalClassModel(model, y_test, y_pred_class, plot=False):
    
    confusion = metrics.confusion_matrix(y_test, y_pred_class)
    TP = confusion[1, 1]
    TN = confusion[0, 0]
    FP = confusion[0, 1]
    FN = confusion[1, 0]
    
    #Visualize Confusion Matrix
    sns.heatmap(confusion,annot=True,fmt="d") 
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    
    false_positive_rate = FP / float(TN + FP)
    print('False Positive Rate:', false_positive_rate)
    
    precision = TP / float(TP + FP)
    print('Precision:',precision)
    
    y_pred_prob = model.predict_proba(X_test)[:,1]
    
    print('Accuracy:', metrics.accuracy_score(y_test, y_pred_class))
    
    print('AUC Score:', metrics.roc_auc_score(y_test, y_pred_prob))
    
    
    roc_auc = metrics.roc_auc_score(y_test, y_pred_prob)
    
    fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob)
    
    if plot == True:
        plt.figure()
        plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
        plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.0])
        plt.rcParams['font.size'] = 12
        plt.title('ROC curve for treatment classifier')
        plt.xlabel('False Positive Rate (1 - Specificity)')
        plt.ylabel('True Positive Rate (Sensitivity)')
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
model3 = LogisticRegression()
model3.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression()

# %%
y_pred3 = model3.predict(X_test)

# %%
accuracy_score = evalClassModel(model3, y_test, y_pred3, True)
accuracy_score
# Out:
# False Positive Rate: 0.24193548387096775
# Precision: 0.7931034482758621
# Accuracy: 0.8326693227091634
# AUC Score: 0.8992252984505968

# %% [markdown]
# ## Decision Tree

# %%
model1 = DecisionTreeClassifier(random_state=1)
model1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
y_pred1 = model1.predict(X_test)

# %%
accuracy_score = evalClassModel(model1, y_test, y_pred1, True)
accuracy_score
# Out:
# False Positive Rate: 0.2661290322580645
# Precision: 0.7401574803149606
# Accuracy: 0.7370517928286853
# AUC Score: 0.7370142240284481

# %% [markdown]
# ## Decision Tree with Hyperparameter tuning

# %%
params = {
    "splitter":("best", "random"), 
    "max_depth":(list(range(1, 20))), 
    "min_samples_split":[2, 3, 4], 
    "min_samples_leaf":list(range(1, 20)), 
}


model = DecisionTreeClassifier(random_state=42)
random_search_cv = RandomizedSearchCV(estimator = model,param_distributions= params,n_iter = 500,
                                      scoring="accuracy", n_jobs=-1, verbose=1, cv=5)

# %%
model2 = random_search_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 1352 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 2500 out of 2500 | elapsed:   15.7s finished

# %%
model2.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 3,
#  'min_samples_leaf': 5,
#  'max_depth': 3}

# %%
y_pred2 = model2.predict(X_test)

# %%
accuracy_score = evalClassModel(model2, y_test, y_pred2, True)
accuracy_score
# Out:
# False Positive Rate: 0.2903225806451613
# Precision: 0.7707006369426752
# Accuracy: 0.8326693227091634
# AUC Score: 0.8961772923545849

# %% [markdown]
# ## KNN classifier with Hyperparameter tuning

# %%
k_range = list(range(1, 31))
weight_options = ['uniform', 'distance']
param_dist = dict(n_neighbors=k_range, weights=weight_options)

knn = KNeighborsClassifier()
model4 = RandomizedSearchCV(knn, param_dist,n_iter=200, cv=5, verbose=2,
                               random_state=42, n_jobs=-1)

#model4 = KNeighborsClassifier(n_neighbors=5)
model4.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:278: UserWarning: The total space of parameters 60 is smaller than n_iter=200. Running 60 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 293 out of 300 | elapsed:    3.7s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    3.7s finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(), n_iter=200,
# ...

# %%
model4.best_params_
# Out:
# {'weights': 'distance', 'n_neighbors': 7}

# %%
y_pred4 = model4.predict(X_test)

# %%
accuracy_score = evalClassModel(model4, y_test, y_pred4, True)
accuracy_score
# Out:
# False Positive Rate: 0.18548387096774194
# Precision: 0.7870370370370371
# Accuracy: 0.7410358565737052
# AUC Score: 0.8300736601473202

# %% [markdown]
# ## Bagging

# %%
model5 = BaggingClassifier()
model5.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# BaggingClassifier()

# %%
y_pred5 = model5.predict(X_test)

# %%
accuracy_score = evalClassModel(model5, y_test, y_pred5, True)
accuracy_score
# Out:
# False Positive Rate: 0.22580645161290322
# Precision: 0.7941176470588235
# Accuracy: 0.8127490039840638
# AUC Score: 0.8682054864109728

# %% [markdown]
# ## Random Forest with Hyperparameter tuning

# %%
n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]
max_features = ['auto', 'sqrt']
max_depth = list(range(1, 20))
max_depth.append(None)
min_samples_split = list(range(1,10))
min_samples_leaf = list(range(1, 20))
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators, 'max_features': max_features,
               'max_depth': max_depth, 'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf, 'bootstrap': bootstrap}

rand_forest = RandomForestClassifier()

rf_random = RandomizedSearchCV(estimator=rand_forest, param_distributions=random_grid, n_iter=20, cv=5, 
                               verbose=2, random_state=42, n_jobs=-1)

# %%
model6 = rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  9.7min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
model6.best_params_
# Out:
# {'n_estimators': 1400,
#  'min_samples_split': 7,
#  'min_samples_leaf': 4,
#  'max_features': 'sqrt',
#  'max_depth': 12,
#  'bootstrap': False}

# %%
y_pred6 = model6.predict(X_test)

# %%
accuracy_score = evalClassModel(model6, y_test, y_pred6, True)
accuracy_score
# Out:
# False Positive Rate: 0.24193548387096775
# Precision: 0.7945205479452054
# Accuracy: 0.8366533864541833
# AUC Score: 0.888747777495555

# %% [markdown]
# ## Ada Boost

# %%
adaboost = AdaBoostClassifier(n_estimators=50,
                         learning_rate=0.5)
model7 = adaboost.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_pred7 = model7.predict(X_test)

# %%
accuracy_score = evalClassModel(model7, y_test, y_pred7, True)
accuracy_score
# Out:
# False Positive Rate: 0.24193548387096775
# Precision: 0.7972972972972973
# Accuracy: 0.8446215139442231
# AUC Score: 0.8966535433070867

# %% [markdown]
# ## Xgboost

# %%
import xgboost
xgboost = xgboost.XGBClassifier(n_estimators = 200,max_depth=10,subsample=0.7,
                               colsample_bytree = 0.2,colsample_bylevel=0.3,
                               learning_rate = 0.3, min_child_weight = 3)
model8 = xgboost.fit(X_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_pred8 = model8.predict(X_test)

# %%
accuracy_score = evalClassModel(model8, y_test, y_pred8, True)
accuracy_score
# Out:
# False Positive Rate: 0.20967741935483872
# Precision: 0.8102189781021898
# Accuracy: 0.8326693227091634
# AUC Score: 0.8977012954025908

# %% [markdown]
# ## LightGBM

# %%
import lightgbm as lgb

lgboost= lgb.LGBMClassifier()

model9 = lgboost.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_pred9 = model9.predict(X_test)

# %%
accuracy_score = evalClassModel(model9, y_test, y_pred9, True)
accuracy_score
# Out:
# False Positive Rate: 0.22580645161290322
# Precision: 0.7910447761194029
# Accuracy: 0.8047808764940239
# AUC Score: 0.8783337566675133

# %% [markdown]
# ## Stacking

# %%
clf1 = KNeighborsClassifier(n_neighbors=7)
clf2 = RandomForestClassifier()
clf3 = GaussianNB()
lr = LogisticRegression()
stack = StackingClassifier(classifiers=[clf1, clf2, clf3], meta_classifier=lr)

model10 = stack.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/mlxtend/classifier/stacking_classification.py:189: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf.fit(X, y)
# /opt/anaconda3/lib/python3.8/site-packages/mlxtend/classifier/stacking_classification.py:189: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X, y)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
y_pred10 = model10.predict(X_test)

# %%
accuracy_score = evalClassModel(model10, y_test, y_pred10, True)
accuracy_score
# Out:
# False Positive Rate: 0.23387096774193547
# Precision: 0.7972027972027972
# Accuracy: 0.8326693227091634
# AUC Score: 0.8746824993649988
